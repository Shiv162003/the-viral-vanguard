# %%
import pandas as pd
import numpy as np

# %%
# NEVER RUN THIS😤

# %%
df=pd.read_csv("data.csv" )

# %%
df
# Out:
#       Sr. No         Sample ID Unnamed: 2        Date  \
# 0        1.0     SSBS/M/2021/1        S-1  04-10-2021
# 1        2.0     SSBS/M/2021/2        S-2  04-10-2021
# 2        3.0     SSBS/M/2021/3        S-3  04-10-2021
# 3        4.0     SSBS/M/2021/4        S-4  04-10-2021
# 4        5.0     SSBS/M/2021/5        S-5  04-10-2021
# ...      ...               ...        ...         ...
# 1295  1301.0  SSBS/M/2022/1301     S-1301  29-09-2022
# 1296  1302.0  SSBS/M/2022/1302     S-1302  29-09-2022
# 1297  1303.0  SSBS/M/2022/1303     S-1303  29-09-2022
# 1298  1304.0  SSBS/M/2022/1304     S-1304  30-09-2022
# 1299  1305.0  SSBS/M/2022/1305     S-1305  30-09-2022
#
#                             Location  Kit used  Ct N   Ct E   Ct RdRp  \
# 0         Sanjeevan hospital Kothrud  Genepath   0.00    0.0     0.00
# 1                  Kothrud Bus depot  Genepath   0.00    0.0     0.00
# 2                 Karve road Kothrud  Genepath   0.00    0.0     0.00
# ...

# %%
for i in range(0,1300):
    print(df["Location"][i])
# Out:
# Sanjeevan hospital Kothrud
# Kothrud Bus depot
# Karve road Kothrud
# Warje Mumbai-Bangalore Highway
# Shivajinagar
# Pune-Mumbai Highway NH, Shivajinagar
# Baner, Mahalunge Bridge
# Baner-Balewadi
# Jai bhavani nagar pashan
# Someshwarwadi
# Dattawadi under rajaram bridge
# Vitthalwadi hingne, off sinhagad road
# Shivajinagar Juna bazaar
# RTO office Yerwada
# Chinchwad, Aditya birla hospital
# Shastrinagar, pimpri
# kasarwadi pimple gurav road
# Pimple gurav, 60 feet road
# Dapodi - Old sangvi Bridge
# Rahatni new DP road
# Kalewadi Adarsh Nagar
# Wolf Colony, Pimpri
# Phugewadi-Dapodi, sai service
# Harris Bridge, Dapodi
# Yerwada Old bund garden
# Vishrantwadi, shantinagar
# Shivajinagar Vaidhawadi
# Shivajinagar Chaturshringi
# Sanjeevan hospital Kothrud
# Karve road Kothrud
# Warje Mumbai-Bangalore Highway
# Kothrud Bus depot
# Baner-Balewadi
# Jai bhavani nagar pashan
# Someshwarwadi
# Pune-Mumbai Highway, Aundh-Sangvi
# Baner, Mahalunge Bridge
# ...

# %%
df2=pd.read_csv("kothrud.csv")

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Sr. No, Sample ID, Unnamed: 2, Date, Location, Kit used, Ct N , Ct E , Ct RdRp, PCR Result]
# Index: []

# %%
for i in range(0,1299):
    x=df["Location"][i]
    if "Kothrud" in x:
        row_to_copy = df.loc[i]
        df2 = df2.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1776609643.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1776609643.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1776609643.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1776609643.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row_to_copy)
# ...

# %%
df2
# Out:
#       Sr. No         Sample ID Unnamed: 2        Date  \
# 0        1.0     SSBS/M/2021/1        S-1  04-10-2021
# 1        2.0     SSBS/M/2021/2        S-2  04-10-2021
# 2        3.0     SSBS/M/2021/3        S-3  04-10-2021
# 28      29.0    SSBS/M/2021/29       S-29  11-10-2021
# 29      30.0    SSBS/M/2021/30       S-30  11-10-2021
# ...      ...               ...        ...         ...
# 1239  1245.0  SSBS/M/2022/1245     S-1245  12-09-2022
# 1259  1265.0  SSBS/M/2022/1265     S-1265  19-09-2022
# 1261  1267.0  SSBS/M/2022/1267     S-1267  19-09-2022
# 1281  1287.0  SSBS/M/2022/1287     S-1287  26-09-2022
# 1283  1289.0  SSBS/M/2022/1289     S-1289  26-09-2022
#
#                         Location  Kit used    Ct N     Ct E  Ct RdRp  \
# 0     Sanjeevan hospital Kothrud  Genepath      0.0      0.0     0.0
# 1              Kothrud Bus depot  Genepath      0.0      0.0     0.0
# 2             Karve road Kothrud  Genepath      0.0      0.0     0.0
# ...

# %%
df3=pd.read_csv("warje.csv")
df3
# Out:
# Empty DataFrame
# Columns: [Sr. No, Sample ID, Unnamed: 2, Date, Location, Kit used, Ct N , Ct E , Ct RdRp, PCR Result]
# Index: []

# %%
for i in range(0,1299):
    x=df["Location"][i]
    if "Warje" in x:
        row_to_copy = df.loc[i]
        df3 = df3.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2335348203.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2335348203.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2335348203.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2335348203.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(row_to_copy)
# ...

# %%
df3
# Out:
#       Sr. No         Sample ID Unnamed: 2        Date  \
# 3        4.0     SSBS/M/2021/4        S-4  04-10-2021
# 30      31.0    SSBS/M/2021/31       S-31  11-10-2021
# 50      51.0    SSBS/M/2021/51       S-51  18-10-2021
# 78      79.0    SSBS/M/2021/79       S-79  25-10-2021
# 102    103.0   SSBS/W/2021/103      S-103  10-11-2021
# 119    120.0   SSBS/W/2021/120      S-120  15-11-2021
# 147    148.0   SSBS/W/2021/148      S-148  22-11-2021
# 175    176.0   SSBS/W/2021/176      S-176  29-11-2021
# 203    204.0   SSBS/W/2021/204      S-204  06-12-2021
# 231    232.0   SSBS/W/2021/232      S-232  13-12-2021
# 259    260.0   SSBS/W/2021/260      S-260  20-12-2021
# 292    293.0   SSBS/W/2021/293      S-293  28-12-2021
# 314    315.0   SSBS/W/2022/315      S-315  03-01-2022
# 342    343.0   SSBS/W/2022/343      S-343  10-01-2022
# 370    371.0   SSBS/W/2022/371      S-371  17-01-2022
# 392    398.0   SSBS/W/2022/398      S-398  24-01-2022
# ...

# %%
df3.shape
# Out:
# (50, 10)

# %%
df4=pd.read_csv("Shivajinagar.csv")
df4
# Out:
# Empty DataFrame
# Columns: [Sr. No, Sample ID, Unnamed: 2, Date, Location, Kit used, Ct N , Ct E , Ct RdRp, PCR Result]
# Index: []

# %%
for i in range(0,1299):
    x=df["Location"][i]
    if "Shivajinagar" in x:
        row_to_copy = df.loc[i]
        df4 = df4.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3588285284.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df4.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3588285284.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df4.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3588285284.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df4.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3588285284.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df4.append(row_to_copy)
# ...

# %%
df5=pd.read_csv("Baner.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Baner" in x:
        row_to_copy = df.loc[i]
        df5 = df5.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1609360307.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5 = df5.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1609360307.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5 = df5.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1609360307.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5 = df5.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1609360307.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5 = df5.append(row_to_copy)
# ...

# %%
df6=pd.read_csv("pashan.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "pashan" in x:
        row_to_copy = df.loc[i]
        df6 = df6.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2305258956.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df6.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2305258956.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df6.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2305258956.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df6.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2305258956.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df6.append(row_to_copy)
# ...

# %%
df7=pd.read_csv("Someshwarwadi.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Someshwarwadi" in x:
        row_to_copy = df.loc[i]
        df7 = df7.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3955268716.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df7 = df7.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3955268716.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df7 = df7.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3955268716.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df7 = df7.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3955268716.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df7 = df7.append(row_to_copy)
# ...

# %%
df8=pd.read_csv("Dattawadi.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Dattawadi" in x:
        row_to_copy = df.loc[i]
        df8= df8.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\272378653.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df8= df8.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\272378653.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df8= df8.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\272378653.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df8= df8.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\272378653.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df8= df8.append(row_to_copy)
# ...

# %%
df9=pd.read_csv("Vitthalwadi.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Vitthalwadi" in x:
        row_to_copy = df.loc[i]
        df9= df9.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3687357626.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df9= df9.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3687357626.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df9= df9.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3687357626.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df9= df9.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3687357626.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df9= df9.append(row_to_copy)
# ...

# %%
df10=pd.read_csv("RTO.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "RTO" in x:
        row_to_copy = df.loc[i]
        df10= df10.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2877576159.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10= df10.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2877576159.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10= df10.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2877576159.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10= df10.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2877576159.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10= df10.append(row_to_copy)
# ...

# %%
df11=pd.read_csv("Chinchwad.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Chinchwad" in x:
        row_to_copy = df.loc[i]
        df11= df11.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\4199799333.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11= df11.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\4199799333.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11= df11.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\4199799333.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11= df11.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\4199799333.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11= df11.append(row_to_copy)
# ...

# %%
df12=pd.read_csv("pimpri.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "pimpri" in x:
        row_to_copy = df.loc[i]
        df12= df12.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1078739289.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12= df12.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1078739289.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12= df12.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1078739289.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12= df12.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1078739289.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12= df12.append(row_to_copy)
# ...

# %%
df13=pd.read_csv("gurav.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "gurav" in x:
        row_to_copy = df.loc[i]
        df13= df13.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1977810980.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df13= df13.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1977810980.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df13= df13.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1977810980.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df13= df13.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1977810980.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df13= df13.append(row_to_copy)
# ...

# %%
df14=pd.read_csv("Dapodi.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Dapodi" in x:
        row_to_copy = df.loc[i]
        df14= df14.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2056092242.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df14= df14.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2056092242.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df14= df14.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2056092242.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df14= df14.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\2056092242.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df14= df14.append(row_to_copy)
# ...

# %%
df15=pd.read_csv("DP.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "DP" in x:
        row_to_copy = df.loc[i]
        df15= df15.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3272311919.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df15= df15.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3272311919.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df15= df15.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3272311919.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df15= df15.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3272311919.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df15= df15.append(row_to_copy)
# ...

# %%
df14
# Out:
#       Sr. No         Sample ID Unnamed: 2        Date  \
# 18      19.0    SSBS/M/2021/19       S-19  07-10-2021
# 22      23.0    SSBS/M/2021/23       S-23  08-10-2021
# 23      24.0    SSBS/M/2021/24       S-24  08-10-2021
# 41      42.0    SSBS/M/2021/42       S-42  13-10-2021
# 42      43.0    SSBS/M/2021/43       S-43  13-10-2021
# ...      ...               ...        ...         ...
# 1256  1262.0  SSBS/M/2022/1262     S-1262  16-09-2022
# 1275  1281.0  SSBS/M/2022/1281     S-1281  22-09-2022
# 1277  1283.0  SSBS/M/2022/1283     S-1283  23-09-2022
# 1278  1284.0  SSBS/M/2022/1284     S-1284  23-09-2022
# 1297  1303.0  SSBS/M/2022/1303     S-1303  29-09-2022
#
#                            Location  Kit used    Ct N  Ct E   Ct RdRp  \
# 18       Dapodi - Old sangvi Bridge  Genepath     31.6  33.2     33.7
# 22    Phugewadi-Dapodi, sai service  Genepath     37.5   0.0     37.5
# 23            Harris Bridge, Dapodi  Genepath      0.0   0.0      0.0
# ...

# %%
df16=pd.read_csv("Kalewadi.csv")
for i in range(0,1299):
    x=df["Location"][i]
    if "Kalewadi" in x:
        row_to_copy = df.loc[i]
        df16= df16.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1710796908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df16= df16.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1710796908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df16= df16.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1710796908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df16= df16.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1710796908.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df16= df16.append(row_to_copy)
# ...

# %%
df15
# Out:
#       Sr. No         Sample ID Unnamed: 2        Date  \
# 19      20.0    SSBS/M/2021/20       S-20  08-10-2021
# 55      56.0    SSBS/M/2021/56       S-56  19-10-2021
# 69      70.0    SSBS/M/2021/70       S-70  22-10-2021
# 83      84.0    SSBS/M/2021/84       S-84  26-10-2021
# 107    108.0   SSBS/W/2021/108      S-108  11-11-2021
# ...      ...               ...        ...         ...
# 1254  1260.0  SSBS/M/2022/1260     S-1260  16-09-2022
# 1267  1273.0  SSBS/M/2022/1273     S-1273  20-09-2022
# 1276  1282.0  SSBS/M/2022/1282     S-1282  23-09-2022
# 1289  1295.0  SSBS/M/2022/1295     S-1295  27-09-2022
# 1298  1304.0  SSBS/M/2022/1304     S-1304  30-09-2022
#
#                               Location  Kit used    Ct N   Ct E   Ct RdRp  \
# 19                 Rahatni new DP road  Genepath     35.6    0.0     35.7
# 55    DP road, Botanical Garden, Aundh  Genepath      0.0    0.0      0.0
# 69                 Rahatni new DP road  Genepath      0.0   37.3      0.0
# ...

# %%
df17=pd.read_csv("Yerwada.csv")
for i in range(0,1299): 
    x=df["Location"][i]
    if "Yerwada" in x:
        row_to_copy = df.loc[i]
        df17= df17.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1602215129.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df17= df17.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1602215129.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df17= df17.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1602215129.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df17= df17.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1602215129.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df17= df17.append(row_to_copy)
# ...

# %%
df18=pd.read_csv("shantinagar.csv")
for i in range(0,1299): 
    x=df["Location"][i]
    if "shantinagar" in x:
        row_to_copy = df.loc[i]
        df18= df18.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3087534185.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df18= df18.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3087534185.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df18= df18.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3087534185.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df18= df18.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\3087534185.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df18= df18.append(row_to_copy)
# ...

# %%
df19=pd.read_csv("Aundh.csv")
for i in range(0,1299): 
    x=df["Location"][i]
    if "Aundh" in x:
        row_to_copy = df.loc[i]
        df19= df19.append(row_to_copy)
# Out:
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1289255597.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df19= df19.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1289255597.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df19= df19.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1289255597.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df19= df19.append(row_to_copy)
# C:\Users\Shiva\AppData\Local\Temp\ipykernel_19828\1289255597.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df19= df19.append(row_to_copy)
# ...

# %%
df2.to_csv('kothrud.csv', index=False)
df3.to_csv('warje.csv', index=False)
df4.to_csv('Shivajinagar.csv', index=False)
df5.to_csv('Baner.csv', index=False)
df6.to_csv('pashan.csv', index=False)
df7.to_csv('Someshwarwadi.csv', index=False)
df8.to_csv('Dattawadi.csv', index=False)
df9.to_csv('Vitthalwadi.csv', index=False)
df10.to_csv('RTO.csv', index=False)
df11.to_csv('Chinchwad.csv', index=False)
df12.to_csv('pimpri.csv', index=False)
df13.to_csv('gurav.csv', index=False)
df14.to_csv('Dapodi.csv', index=False)
df15.to_csv('DP.csv', index=False)
df16.to_csv('Kalewadi.csv', index=False)
df17.to_csv('Yerwada.csv', index=False)
df18.to_csv('shantinagar.csv', index=False)
df19.to_csv('Aundh.csv', index=False)
